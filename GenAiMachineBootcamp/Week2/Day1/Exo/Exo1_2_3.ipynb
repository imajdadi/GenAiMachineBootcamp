# %%
#Exo1
#1--Qu'est-ce que l'analyse de données ?
#L'analyse des données est le processus d'examen, de nettoyage, 
#de transformation et de modélisation des données afin de découvrir des informations utiles, 
#de tirer des conclusions et de soutenir la prise de décision.
#2--Pourquoi l’analyse des données est-elle importante dans les contextes modernes ?
#L’analyse des données est cruciale dans les contextes modernes pour prendre des décisions basées sur des faits, 
#optimiser les performances et anticiper les risques. 
#Elle permet d'explorer les tendances et d’innover pour rester compétitif dans un environnement en constante évolution.
#3--Énumérez et décrivez trois domaines dans lesquels l’analyse des données est appliquée aujourd’hui.
#Santé : L'analyse des données est utilisée pour améliorer les soins de santé, prévoir les épidémies et
#personnaliser les traitements en fonction des données médicales des patients.
#Marketing : Elle permet d'analyser les comportements des consommateurs,
# de segmenter le marché et de personnaliser les campagnes publicitaires pour augmenter les ventes.
#Finance : L'analyse des données aide à détecter les fraudes, 
# à évaluer les risques financiers et à optimiser les investissements en utilisant des données financières en temps réel.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fc3f3f7f-46ff-4fca-8924-5b3bb06f7e49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc3f3f7f-46ff-4fca-8924-5b3bb06f7e49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import zipfile
import pandas as pd

# Nom du fichier ZIP
nom_zip = "Credit Card Approvals (Clean Data).zip"

# Ouvrir le fichier ZIP
with zipfile.ZipFile(nom_zip, 'r') as zipf:
    for fichier in zipf.namelist():  # Liste des fichiers dans le ZIP
        # Ouvrir chaque fichier CSV et le lire avec pandas
        with zipf.open(fichier) as f:
            df = pd.read_csv(f)

            # Afficher des informations sur le DataFrame
            print(f"Fichier : {fichier}")
            df.info()  # Informations sur le DataFrame
            print("\nRésumé statistique :")
            print(df.describe())  # Afficher un résumé statistique des colonnes numériques
            print("\nPremières lignes :")
            print(df.head())  # Afficher les premières lignes
            print("\n" + "="*50 + "\n")
            print("Types de données dans chaque colonne:")
            print(df.dtypes)

# Fonction pour catégoriser les colonnes
def categoriser_colonnes(df):
    for col in df.columns:
        print(f"Colonne : {col}")

        # Vérification du type de données
        if df[col].dtype == 'object':
            print("Type : Qualitative (Catégorielle)")
            # Vérification s'il s'agit de données ordonnées
            if len(df[col].unique()) < 10:  # Si il y a peu de catégories
                print("Sous-type : Catégorielle (probablement qualitative ordonnée ou nominale)")
            else:
                print("Sous-type : Catégorielle (probablement qualitative nominale)")

        elif df[col].dtype in ['int64', 'float64']:
            print("Type : Quantitative (Numérique)")
            # Vérification si la donnée est discrète ou continue
            if df[col].nunique() > 10:  # Si le nombre de valeurs uniques est élevé, probablement continue
                print("Sous-type : Quantitative Continue")
            else:
                print("Sous-type : Quantitative Discrète")

        print("-" * 50)

# Catégoriser les colonnes du DataFrame
categoriser_colonnes(df)
# Out:
# Fichier : Credit Card Approvals (Clean Data)/clean_dataset.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# ...

# %%
import zipfile
import pandas as pd

# Nom du fichier ZIP
nom_zip = "Global Trends in Mental Health Disorder.zip"

# Ouvrir le fichier ZIP
with zipfile.ZipFile(nom_zip, 'r') as zipf:
    for fichier in zipf.namelist():  # Liste des fichiers dans le ZIP
        # Ouvrir chaque fichier CSV et le lire avec pandas
        with zipf.open(fichier) as f:
            df = pd.read_csv(f)

            # Afficher des informations sur le DataFrame
            print(f"Fichier : {fichier}")
            df.info()  # Informations sur le DataFrame
            print("\nRésumé statistique :")
            print(df.describe())  # Afficher un résumé statistique des colonnes numériques
            print("\nPremières lignes :")
            print(df.head())  # Afficher les premières lignes
            print("\n" + "="*50 + "\n")
            print("Types de données dans chaque colonne:")
            print(df.dtypes)

# Fonction pour catégoriser les colonnes
def categoriser_colonnes(df):
    for col in df.columns:
        print(f"Colonne : {col}")

        # Vérification du type de données
        if df[col].dtype == 'object':
            print("Type : Qualitative (Catégorielle)")
            # Vérification s'il s'agit de données ordonnées
            if len(df[col].unique()) < 10:  # Si il y a peu de catégories
                print("Sous-type : Catégorielle (probablement qualitative ordonnée ou nominale)")
            else:
                print("Sous-type : Catégorielle (probablement qualitative nominale)")

        elif df[col].dtype in ['int64', 'float64']:
            print("Type : Quantitative (Numérique)")
            # Vérification si la donnée est discrète ou continue
            if df[col].nunique() > 10:  # Si le nombre de valeurs uniques est élevé, probablement continue
                print("Sous-type : Quantitative Continue")
            else:
                print("Sous-type : Quantitative Discrète")

        print("-" * 50)

# Catégoriser les colonnes du DataFrame
categoriser_colonnes(df)
# Out:
# Fichier : Global Trends in Mental Health Disorder/Mental health Depression disorder Data.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# ...

# %%
import zipfile
import pandas as pd

# Nom du fichier ZIP
nom_zip = "How Much Sleep Do Americans.zip"

# Ouvrir le fichier ZIP
with zipfile.ZipFile(nom_zip, 'r') as zipf:
    for fichier in zipf.namelist():  # Liste des fichiers dans le ZIP
        # Ouvrir chaque fichier CSV et le lire avec pandas
        with zipf.open(fichier) as f:
            df = pd.read_csv(f)

            # Afficher des informations sur le DataFrame
            print(f"Fichier : {fichier}")
            df.info()  # Informations sur le DataFrame
            print("\nRésumé statistique :")
            print(df.describe())  # Afficher un résumé statistique des colonnes numériques
            print("\nPremières lignes :")
            print(df.head())  # Afficher les premières lignes
            print("\n" + "="*50 + "\n")
            print("Types de données dans chaque colonne:")
            print(df.dtypes)

# Fonction pour catégoriser les colonnes
def categoriser_colonnes(df):
    for col in df.columns:
        print(f"Colonne : {col}")

        # Vérification du type de données
        if df[col].dtype == 'object':
            print("Type : Qualitative (Catégorielle)")
            # Vérification s'il s'agit de données ordonnées
            if len(df[col].unique()) < 10:  # Si il y a peu de catégories
                print("Sous-type : Catégorielle (probablement qualitative ordonnée ou nominale)")
            else:
                print("Sous-type : Catégorielle (probablement qualitative nominale)")

        elif df[col].dtype in ['int64', 'float64']:
            print("Type : Quantitative (Numérique)")
            # Vérification si la donnée est discrète ou continue
            if df[col].nunique() > 10:  # Si le nombre de valeurs uniques est élevé, probablement continue
                print("Sous-type : Quantitative Continue")
            else:
                print("Sous-type : Quantitative Discrète")

        print("-" * 50)

# Catégoriser les colonnes du DataFrame
categoriser_colonnes(df)
# Out:
# Fichier : How Much Sleep Do Americans/Time Americans Spend Sleeping.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB
#
# Résumé statistique :
#             index         Year  Avg hrs per day sleeping  Standard Error
# ...
